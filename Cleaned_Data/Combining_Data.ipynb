# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %% [markdown]
# # Columns
# Company_Name <br>
# Date_of_leak <br>
# Data_Type <br>
# Company_Address <br>
# Company_Country <br>
# Industry_Type <br>

# %% [markdown]
# ### Importing CSVs
# 1. Lorenz group
# 2. PLAY NEWS group
# 3. Medusa group
# 4. 8Base group
# 5. Lockbit group

# %%
Lorenz = pd.read_csv("Lorenz.csv")
PlayNews = pd.read_csv("PlayNews.csv")
Medusa = pd.read_csv("Medusa.csv")
EightBase = pd.read_csv("8Base.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File pandas\_libs\parsers.pyx:1119, in pandas._libs.parsers.TextReader._convert_tokens()
#
# File pandas\_libs\parsers.pyx:1244, in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# File pandas\_libs\parsers.pyx:1259, in pandas._libs.parsers.TextReader._string_convert()
#
# File pandas\_libs\parsers.pyx:1450, in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe1 in position 9: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[26], line 3
#       1 Lorenz = pd.read_csv("Lorenz.csv")
#       2 PlayNews = pd.read_csv("PlayNews.csv")
# ----> 3 Medusa = pd.read_csv("Medusa.csv")
#       4 EightBase = pd.read_csv("8Base.csv")
#
# File ~\Anaconda3\lib\site-packages\pandas\io\parsers.py:686, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     633     engine_specified = False
#     635 kwds.update(
#     636     delimiter=delimiter,
#     637     engine=engine,
#    (...)
#     683     skip_blank_lines=skip_blank_lines,
#     684 )
# --> 686 return _read(filepath_or_buffer, kwds)
#
# File ~\Anaconda3\lib\site-packages\pandas\io\parsers.py:458, in _read(filepath_or_buffer, kwds)
#     455     return parser
#     457 try:
# --> 458     data = parser.read(nrows)
#     459 finally:
#     460     parser.close()
#
# File ~\Anaconda3\lib\site-packages\pandas\io\parsers.py:1196, in TextFileReader.read(self, nrows)
#    1194 def read(self, nrows=None):
#    1195     nrows = _validate_integer("nrows", nrows)
# -> 1196     ret = self._engine.read(nrows)
#    1198     # May alter columns / col_dict
#    1199     index, columns, col_dict = self._create_index(ret)
#
# File ~\Anaconda3\lib\site-packages\pandas\io\parsers.py:2155, in CParserWrapper.read(self, nrows)
#    2153 def read(self, nrows=None):
#    2154     try:
# -> 2155         data = self._reader.read(nrows)
#    2156     except StopIteration:
#    2157         if self._first_chunk:
#
# File pandas\_libs\parsers.pyx:847, in pandas._libs.parsers.TextReader.read()
#
# File pandas\_libs\parsers.pyx:862, in pandas._libs.parsers.TextReader._read_low_memory()
#
# File pandas\_libs\parsers.pyx:941, in pandas._libs.parsers.TextReader._read_rows()
#
# File pandas\_libs\parsers.pyx:1073, in pandas._libs.parsers.TextReader._convert_column_data()
#
# File pandas\_libs\parsers.pyx:1126, in pandas._libs.parsers.TextReader._convert_tokens()
#
# File pandas\_libs\parsers.pyx:1244, in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# File pandas\_libs\parsers.pyx:1259, in pandas._libs.parsers.TextReader._string_convert()
#
# File pandas\_libs\parsers.pyx:1450, in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe1 in position 9: invalid continuation byte

# %%
Lorenz = Lorenz[['Company_Name', 'Date_of_leak', 'Company_Address', 'Company_Country', 'Industry_Type', 'Personal Identifiable Information (PII)','Financial Data','Healthcare Information','Employee and HR Data','Intellectual Property and Trade Secrets','Customer and Client Data','Legal Documents','Government and Defense Information','Educational Data','Credentials and Access Information','Databases','Website Data','Backup Data','Video and Surveillance Footage','Social Media Data','Utility and Infrastructure Data','Sensitive Communication']]
llist = ["Lorenz"]*Lorenz.shape[0]
Lorenz['Ransomware_Group'] = llist

# %%
EightBase = EightBase[['Company_Name', 'Date_of_leak', 'Company_Address', 'Company_Country', 'Industry_Type', 'Personal Identifiable Information (PII)','Financial Data','Healthcare Information','Employee and HR Data','Intellectual Property and Trade Secrets','Customer and Client Data','Legal Documents','Government and Defense Information','Educational Data','Credentials and Access Information','Databases','Website Data','Backup Data','Video and Surveillance Footage','Social Media Data','Utility and Infrastructure Data','Sensitive Communication']]
llist = ["8Base"]*EightBase.shape[0]
EightBase['Ransomware_Group'] = llist

# %%
PlayNews = PlayNews[['Company_Name', 'Date_of_leak', 'Company_Address', 'Company_Country', 'Industry_Type', 'Personal Identifiable Information (PII)','Financial Data','Healthcare Information','Employee and HR Data','Intellectual Property and Trade Secrets','Customer and Client Data','Legal Documents','Government and Defense Information','Educational Data','Credentials and Access Information','Databases','Website Data','Backup Data','Video and Surveillance Footage','Social Media Data','Utility and Infrastructure Data','Sensitive Communication']]
llist = ["PlayNews"]*PlayNews.shape[0]
PlayNews['Ransomware_Group'] = llist

# %%
Medusa = Medusa[['Company_Name', 'Date_of_leak', 'Company_Address', 'Company_Country', 'Industry_Type', 'Personal Identifiable Information (PII)','Financial Data','Healthcare Information','Employee and HR Data','Intellectual Property and Trade Secrets','Customer and Client Data','Legal Documents','Government and Defense Information','Educational Data','Credentials and Access Information','Databases','Website Data','Backup Data','Video and Surveillance Footage','Social Media Data','Utility and Infrastructure Data','Sensitive Communication']]
llist = ["Medusa"]*Medusa.shape[0]
Medusa['Ransomware_Group'] = llist

# %% [markdown]
# ### Concatenating all the dataframes

# %%
Final_DF = pd.concat([Lorenz, EightBase], axis=0)

# %% [markdown]
# ### Analyzing basic graphs (before tableau)

# %% [markdown]
# #### Ransomware Group Activity

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
sb.barplot(x=Final_DF.Ransomware_Group.value_counts().index, y=Final_DF.Ransomware_Group.value_counts())
# Out:
# C:\Users\samik\AppData\Local\Temp\ipykernel_12536\4289784549.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# <AxesSubplot:ylabel='Ransomware_Group'>

# %% [markdown]
# #### Industry Type attacked

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
sb.barplot(x=Final_DF.Industry_Type.value_counts().index, y=Final_DF.Industry_Type.value_counts())
# Out:
# C:\Users\samik\AppData\Local\Temp\ipykernel_12536\639746881.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# <AxesSubplot:ylabel='Industry_Type'>

# %% [markdown]
# #### Countries Attacked

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
sb.barplot(x=Final_DF.Company_Country.value_counts().index, y=Final_DF.Company_Country.value_counts())
# Out:
# C:\Users\samik\AppData\Local\Temp\ipykernel_9332\1545259870.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# <AxesSubplot:ylabel='Company_Country'>

# %%
Final_DF.to_csv("Combined.csv")
